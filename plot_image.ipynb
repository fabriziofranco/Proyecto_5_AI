# %%
import torch
import torch.nn as nn
import torchvision
import torch.utils.data as data
import torchvision.transforms as transforms
import torch.nn.functional as F
import utils
import warnings
import model_1
import random
import os
import shutil
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

# %%
seed = 3
random.seed(seed)
torch.manual_seed(seed)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
AB_scale = 128
width = height = 256
batch_size = 32
datasets = ['anime','doberman','mariposas', 'landscapes']
indice_dataset = 0

# %%
img_transform = transforms.Compose([transforms.ToTensor()]) 
dataset = utils.LabDataSet(f'data/{datasets[indice_dataset]}_{width}',
                img_transform, train_size=20, test_size=10, height=height, width=width, seed=seed)

# %%
img = dataset.train_set[0]
l = img[0]
a = img[1][0]
b = img[1][1]

print(dataset.total_imgs[dataset.train_idx[0]])

# img = []
# for i in range(len(l)):
#     img.append([])
#     for j in range(len(l[0])):
#         img[i].append([l[i][j], a[i][j], b[i][j]])

# plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/carlos/Documents/utec/2022-1/ia/proyectos/Proyecto_5_AI/plot_image.ipynb Cell 5' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/home/carlos/Documents/utec/2022-1/ia/proyectos/Proyecto_5_AI/plot_image.ipynb#ch0000004?line=2'>3</a> a = img[1][0]
#       <a href='vscode-notebook-cell:/home/carlos/Documents/utec/2022-1/ia/proyectos/Proyecto_5_AI/plot_image.ipynb#ch0000004?line=3'>4</a> b = img[1][1]
# ----> <a href='vscode-notebook-cell:/home/carlos/Documents/utec/2022-1/ia/proyectos/Proyecto_5_AI/plot_image.ipynb#ch0000004?line=5'>6</a> print(dataset.total_imgs[dataset.train_idx[0]])
#
# AttributeError: 'LabDataSet' object has no attribute 'train_idx'

# %%
plt.imshow(l, cmap="gray")

# %%
plt.imshow(a)

# %%
plt.imshow(b, cmap="Blues")
